# %%
import glob

# %% [markdown]
# You can find the details of the glob module here:
#
# * [https://docs.python.org/3/library/glob.html](https://docs.python.org/3/library/glob.html)
#
# But the essence of the module is that you can easily get lists of files and process them (the list includes the file paths and from them you can open using a variety of Pandas methods like [`read_csv`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html).
#
# For example, we can get all the `meet.csv` files in the year 2015 with the following (recall the first two digits of the folder indicate the year, so 15XX indicate 2015).

# %%
file_list_2015 = glob.glob("./data/**/15*/meet.csv")

# %%
file_list
# Out:
# ['./data/capo/1508/meet.csv',
#  './data/capo/1505/meet.csv',
#  './data/capo/1501/meet.csv',
#  './data/capo/1504/meet.csv',
#  './data/capo/1503/meet.csv',
#  './data/capo/1509/meet.csv',
#  './data/capo/1512/meet.csv',
#  './data/capo/1502/meet.csv',
#  './data/capo/1511/meet.csv',
#  './data/capo/1510/meet.csv',
#  './data/capo/1506/meet.csv',
#  './data/capo/1507/meet.csv',
#  './data/irishpo/1501/meet.csv',
#  './data/irishpo/1503/meet.csv',
#  './data/irishpo/1502/meet.csv',
#  './data/gpc-nz/1508/meet.csv',
#  './data/gpc-nz/1505/meet.csv',
#  './data/gpc-nz/1501/meet.csv',
#  './data/gpc-nz/1504/meet.csv',
#  './data/gpc-nz/1503/meet.csv',
#  './data/gpc-nz/1502/meet.csv',
#  './data/gpc-nz/1506/meet.csv',
#  './data/gpc-nz/1507/meet.csv',
#  './data/epf/1508/meet.csv',
#  './data/epf/1505/meet.csv',
#  './data/epf/1501/meet.csv',
#  './data/epf/1504/meet.csv',
#  './data/epf/1503/meet.csv',
#  './data/epf/1509/meet.csv',
#  './data/epf/1502/meet.csv',
# ...
